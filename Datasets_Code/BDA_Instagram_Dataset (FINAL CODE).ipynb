# %% [markdown]
# FINAL INSTAGRAM DATASETS

# %%
#bda1

import csv
import random
from faker import Faker

fake = Faker()

country_list = ["Brazil", "China", "Ireland", "Sweden", "Belgium", "Sweden", "Austria", "Denmark", "Netherlands", 
                "United Arab Emirates", "Norway", "New Zealand", "Denmark", "Saudi Arabia", "Pakistan", 
               "India", "United States", "Indonesia", "Japan", "United Kingdom", "Mexico", "France", 
                "Germany", "Italy", "Argentina", "Spain", "Russia", "South Korea", "Philippines",  "Colombia",
               "Thailand", "Canada", "Australia", "Egypt", "Iraq", "Malaysia", "Chile", "Poland", 
                "Vietnam", "Morocco", "Peru", "Algeria", "South Africa", "Portugal", "Romania", 
                "Greece", "Bangladesh", "Switzerland", "Hong Kong", "Singapore", "Costa Rica"]

location_list = ["United States", "United Kingdom", "Canada", "Australia", "France", "Germany", "Japan", "India", 
                "Brazil", "China", "Spain", "Russia", "Indonesia", "South Korea", "Thailand", 
                "Philippines", "Mexico", "Colombia", "Argentina", "Ireland", "Sweden", "Belgium", 
                "Sweden", "Austria", "Denmark", "Netherlands", "United Arab Emirates", "Norway", "Italy", 
                "New Zealand", "Denmark", "Saudi Arabia"]

category_list = ["Sports", "Music", "Dance", "Art", "Lifestyle", "Beauty", "Fashion", "Comedy","Business & Careers",
                 "Technology","Food & Cooking", "Modeling", "Cinema/Theatre", "Fitness", "Literature & Journalism", 
                 "Spirituality", "Animals", "Family", "Education", "Management & Marketing", "Photography", "Media",
                 "Games", "Inspirational quotes", "Retail", "Real Estate", "Travel", "Medical"]


gender_list = ["Male", "Female"]

columns = ["Influencer_insta_username", "Influencer_real_name", "Content_category",
           "Number_of_followers", "Audience_country", "Influencer_location",
           "Audience_age_range", "Engagement_rate", "Majority_audience_gender", "Youtuber", 
           "Cost_per_post", "Avg_likes_partnership_posts"]

def generate_fake_row():
    influencer_insta_username = fake.user_name()
    influencer_real_name = fake.name() if random.random() > 0.01 else ""
    content_category = random.choice(category_list)

    number_of_followers = random.uniform(900, 150000)  
    followers_str = f"{number_of_followers:.0f}"  

    audience_country = random.choice(country_list) if random.random() > 0.01 else ""
    influencer_location = random.choice(location_list) if random.random() > 0.01 else ""

    min_age = random.randint(1, 19) * 5  
    max_age = min_age + 5  
    audience_age_range = f"{min_age}-{max_age}"  

 
    
    majority_audience_gender = random.choice(gender_list) if random.random() > 0.01 else ""
    youtuber = random.choice(["Yes", "No"]) if random.random() > 0.01 else ""

    if number_of_followers >= 1000 and number_of_followers < 10000:
        cost_per_post = "10000"
    elif number_of_followers >= 10000 and number_of_followers < 50000:
        cost_per_post = "50000"
    elif number_of_followers >= 50000 and number_of_followers < 500000:
        cost_per_post = "200000"
    elif number_of_followers >= 500000 and number_of_followers < 1000000:
        cost_per_post = "500000"
    else:
        cost_per_post = "800000+"

    

    engagement_rate = round(random.uniform(0.5, 6.5), 1)
        
    if engagement_rate < 1:
        avg_likes_partnership_posts = random.randint(500, 1000)
    elif 1 <= engagement_rate <= 3.5:
        avg_likes_partnership_posts = random.randint(1000, 5000)
    elif 3.5 < engagement_rate <= 6:
        avg_likes_partnership_posts = random.randint(5000, 10000)
    else:
        avg_likes_partnership_posts = random.randint(10000, 50000)
   
    avg_likes_str = f"{avg_likes_partnership_posts}"  

    return [influencer_insta_username, influencer_real_name, content_category,
            followers_str, audience_country, influencer_location,
            audience_age_range, engagement_rate, majority_audience_gender, youtuber, cost_per_post, avg_likes_str]

data = [generate_fake_row() for _ in range(200000)]

with open("bda_data1.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(columns)  
    writer.writerows(data) 

print("CSV file generated successfully.")
# Out:
# CSV file generated successfully.

# %%
#bda2

import csv
import random
from faker import Faker

fake = Faker()

country_list = ["Brazil", "China", "Ireland", "Sweden", "Belgium", "Sweden", "Austria", "Denmark", "Netherlands", 
                "United Arab Emirates", "Norway", "New Zealand", "Denmark", "Saudi Arabia", "Pakistan", 
               "India", "United States", "Indonesia", "Japan", "United Kingdom", "Mexico", "France", 
                "Germany", "Italy", "Argentina", "Spain", "Russia", "South Korea", "Philippines",  "Colombia",
               "Thailand", "Canada", "Australia", "Egypt", "Iraq", "Malaysia", "Chile", "Poland", 
                "Vietnam", "Morocco", "Peru", "Algeria", "South Africa", "Portugal", "Romania", 
                "Greece", "Bangladesh", "Costa Rica"]

location_list = ["United States", "United Kingdom", "Canada", "Australia", "France", "Germany", "Japan", "India", 
                "Brazil", "China", "Spain", "Russia", "Indonesia", "South Korea", "Thailand", 
                "Philippines", "Ireland", "Sweden", "Belgium", 
                "Sweden", "Austria", "Denmark", "Netherlands", "United Arab Emirates", "Norway", "Italy", 
                "New Zealand", "Denmark", "Saudi Arabia"]

category_list = ["Sports", "Music", "Dance", "Art", "Lifestyle", "Beauty", "Fashion", "Comedy","Business & Careers",
                 "Technology","Food & Cooking", "Modeling", "Cinema/Theatre", "Fitness", "Literature & Journalism", 
                 "Spirituality", "Animals", "Family", "Education", "Management & Marketing", "Photography", "Media",
                 "Games", "Real Estate", "Travel"]


gender_list = ["Male", "Female"]

columns = ["Influencer_insta_username", "Influencer_real_name", "Content_category",
           "Number_of_followers", "Audience_country", "Influencer_location",
           "Audience_age_range", "Engagement_rate", "Majority_audience_gender", "Youtuber", 
           "Cost_per_post", "Avg_likes_partnership_posts"]

def generate_fake_row():
    influencer_insta_username = fake.user_name()
    influencer_real_name = fake.name() if random.random() > 0.01 else ""
    content_category = random.choice(category_list)

    number_of_followers = random.uniform(155000, 500000)  
    followers_str = f"{number_of_followers:.0f}" 

    audience_country = random.choice(country_list) if random.random() > 0.01 else ""
    influencer_location = random.choice(location_list) if random.random() > 0.01 else ""

    min_age = random.randint(1, 19) * 5  
    max_age = min_age + 5  
    audience_age_range = f"{min_age}-{max_age}"  
    
    majority_audience_gender = random.choice(gender_list) if random.random() > 0.01 else ""
    youtuber = random.choice(["Yes", "No"]) if random.random() > 0.01 else ""

    if number_of_followers >= 1000 and number_of_followers < 10000:
        cost_per_post = "10000"
    elif number_of_followers >= 10000 and number_of_followers < 50000:
        cost_per_post = "50000"
    elif number_of_followers >= 50000 and number_of_followers < 500000:
        cost_per_post = "200000"
    elif number_of_followers >= 500000 and number_of_followers < 1000000:
        cost_per_post = "500000"
    else:
        cost_per_post = "800000+"

    

    engagement_rate = round(random.uniform(1, 5), 1)
        
    if engagement_rate < 1:
        avg_likes_partnership_posts = random.randint(500, 1000)
    elif 1 <= engagement_rate <= 3.5:
        avg_likes_partnership_posts = random.randint(1000, 5000)
    elif 3.5 < engagement_rate <= 6:
        avg_likes_partnership_posts = random.randint(5000, 10000)
    else:
        avg_likes_partnership_posts = random.randint(10000, 50000)
   
    avg_likes_str = f"{avg_likes_partnership_posts}"  

    return [influencer_insta_username, influencer_real_name, content_category,
            followers_str, audience_country, influencer_location,
            audience_age_range, engagement_rate, majority_audience_gender, youtuber, cost_per_post, avg_likes_str]

data = [generate_fake_row() for _ in range(350000)]

with open("bda_data2.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(columns) 
    writer.writerows(data) 

print("CSV file generated successfully.")
# Out:
# CSV file generated successfully.

# %%
#bda3

import csv
import random
from faker import Faker

fake = Faker()

country_list = ["Brazil", "China", "Ireland", "Sweden", "Belgium", "Sweden", "Austria", "Denmark", "Netherlands", 
                "United Arab Emirates", "Norway", "New Zealand", "Denmark", "Saudi Arabia", "Pakistan", 
               "India", "United States", "Indonesia", "Japan", "United Kingdom", "Mexico", "France", 
                "Germany", "Italy", "Argentina", "Spain", "Russia", "South Korea", "Philippines",  "Colombia",
               "Thailand", "Canada", "Australia", "Egypt", "Iraq", "Malaysia", "Chile", "Poland", 
                "Vietnam", "Morocco", "Portugal", "Romania", "Greece", "Bangladesh", "Costa Rica"]

location_list = ["United States", "United Kingdom", "Canada", "Australia", "France", "Germany", "Japan", "India", 
                "Brazil", "China", "Spain", "Russia", "Indonesia", "South Korea", "Thailand", 
                "Philippines", "Ireland", "Sweden", "Belgium", 
                "Sweden", "Austria", "Denmark", "Netherlands", "Italy", "New Zealand", "Denmark"]

category_list = ["Sports", "Music", "Dance", "Art", "Lifestyle", "Beauty", "Fashion", "Comedy","Business & Careers",
                 "Technology","Food & Cooking", "Modeling", "Cinema/Theatre", "Fitness", "Literature & Journalism", "Animals", 
                 "Family", "Education", "Management & Marketing", "Photography", "Media", "Games", "Travel"]


gender_list = ["Male", "Female"]

columns = ["Influencer_insta_username", "Influencer_real_name", "Content_category",
           "Number_of_followers", "Audience_country", "Influencer_location",
           "Audience_age_range", "Engagement_rate", "Majority_audience_gender", "Youtuber", 
           "Cost_per_post", "Avg_likes_partnership_posts"]

def generate_fake_row():
    influencer_insta_username = fake.user_name()
    influencer_real_name = fake.name() if random.random() > 0.01 else ""
    content_category = random.choice(category_list)

    number_of_followers = random.uniform(510000, 1000000)  
    followers_str = f"{number_of_followers:.0f}"  

    audience_country = random.choice(country_list) if random.random() > 0.01 else ""
    influencer_location = random.choice(location_list) if random.random() > 0.01 else ""

    min_age = random.randint(1, 19) * 5  
    max_age = min_age + 5  
    audience_age_range = f"{min_age}-{max_age}"  
 
    
    majority_audience_gender = random.choice(gender_list) if random.random() > 0.01 else ""
    youtuber = random.choice(["Yes", "No"]) if random.random() > 0.01 else ""

    if number_of_followers >= 1000 and number_of_followers < 10000:
        cost_per_post = "10000"
    elif number_of_followers >= 10000 and number_of_followers < 50000:
        cost_per_post = "50000"
    elif number_of_followers >= 50000 and number_of_followers < 500000:
        cost_per_post = "200000"
    elif number_of_followers >= 500000 and number_of_followers < 1000000:
        cost_per_post = "500000"
    else:
        cost_per_post = "800000+"

    

    engagement_rate = round(random.uniform(1.5, 3), 1)
        
    if engagement_rate < 1:
        avg_likes_partnership_posts = random.randint(500, 1000)
    elif 1 <= engagement_rate <= 3.5:
        avg_likes_partnership_posts = random.randint(1000, 5000)
    elif 3.5 < engagement_rate <= 6:
        avg_likes_partnership_posts = random.randint(5000, 10000)
    else:
        avg_likes_partnership_posts = random.randint(10000, 50000)
   
    avg_likes_str = f"{avg_likes_partnership_posts}"  

    return [influencer_insta_username, influencer_real_name, content_category,
            followers_str, audience_country, influencer_location,
            audience_age_range, engagement_rate, majority_audience_gender, youtuber, cost_per_post, avg_likes_str]

data = [generate_fake_row() for _ in range(250000)]

with open("bda_data3.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(columns)  
    writer.writerows(data)  

print("CSV file generated successfully.")
# Out:
# CSV file generated successfully.

# %%
#bda4

import csv
import random
from faker import Faker

fake = Faker()

country_list = ["Brazil", "China", "Ireland", "Sweden", "Belgium", "Sweden", "Austria", "Denmark", "Netherlands", 
                "United Arab Emirates", "Norway", "New Zealand", "Denmark", "Saudi Arabia", "Pakistan", 
               "India", "United States", "Indonesia", "Japan", "United Kingdom", "Mexico", "France", 
                "Germany", "Italy", "Canada", "Australia", "Egypt", "Iraq", "Malaysia", "Chile", "Poland", 
                "Vietnam", "Morocco", "Portugal", "Romania", "Greece", "Bangladesh", "Costa Rica"]

location_list = ["United States", "United Kingdom", "Canada", "Australia", "France", "Germany", "Japan", "India", 
                "Brazil", "China", "Spain", "Russia", "Indonesia", "South Korea", "Thailand", 
                "Philippines", "Ireland", "Sweden", "Belgium", 
                "Sweden", "Austria", "Denmark", "Netherlands", "Italy", "New Zealand", "Denmark"]

category_list = ["Sports", "Music", "Dance", "Art", "Lifestyle", "Beauty", "Fashion", "Comedy","Business & Careers",
                 "Technology","Food & Cooking", "Modeling", "Cinema/Theatre", "Fitness", 
                 "Family", "Education", "Management & Marketing", "Photography", "Media", "Games", "Travel"]


gender_list = ["Male", "Female"]

columns = ["Influencer_insta_username", "Influencer_real_name", "Content_category",
           "Number_of_followers", "Audience_country", "Influencer_location",
           "Audience_age_range", "Engagement_rate", "Majority_audience_gender", "Youtuber", 
           "Cost_per_post", "Avg_likes_partnership_posts"]

def generate_fake_row():
    influencer_insta_username = fake.user_name()
    influencer_real_name = fake.name() if random.random() > 0.01 else ""
    content_category = random.choice(category_list)

    number_of_followers = random.uniform(1000000, 10000000)  
    followers_str = f"{number_of_followers:.0f}"  

    audience_country = random.choice(country_list) if random.random() > 0.01 else ""
    influencer_location = random.choice(location_list) if random.random() > 0.01 else ""

    min_age = random.randint(1, 19) * 5  
    max_age = min_age + 5  
    audience_age_range = f"{min_age}-{max_age}"  
 
    
    majority_audience_gender = random.choice(gender_list) if random.random() > 0.01 else ""
    youtuber = random.choice(["Yes", "No"]) if random.random() > 0.01 else ""

    if number_of_followers >= 1000 and number_of_followers < 10000:
        cost_per_post = "10000"
    elif number_of_followers >= 10000 and number_of_followers < 50000:
        cost_per_post = "50000"
    elif number_of_followers >= 50000 and number_of_followers < 500000:
        cost_per_post = "200000"
    elif number_of_followers >= 500000 and number_of_followers < 1000000:
        cost_per_post = "500000"
    else:
        cost_per_post = "800000+"

    

    engagement_rate = round(random.uniform(0.5, 6), 1)
        
    if engagement_rate < 1:
        avg_likes_partnership_posts = random.randint(500, 1000)
    elif 1 <= engagement_rate <= 3.5:
        avg_likes_partnership_posts = random.randint(1000, 5000)
    elif 3.5 < engagement_rate <= 6:
        avg_likes_partnership_posts = random.randint(5000, 10000)
    else:
        avg_likes_partnership_posts = random.randint(10000, 50000)
   
    avg_likes_str = f"{avg_likes_partnership_posts}"  

    return [influencer_insta_username, influencer_real_name, content_category,
            followers_str, audience_country, influencer_location,
            audience_age_range, engagement_rate, majority_audience_gender, youtuber, cost_per_post, avg_likes_str]

data = [generate_fake_row() for _ in range(200000)]

with open("bda_data4.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(columns)  
    writer.writerows(data)  

print("CSV file generated successfully.")
# Out:
# CSV file generated successfully.
